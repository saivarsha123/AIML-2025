# %% [markdown]
# <a href="https://colab.research.google.com/github/saivarsha123/AIML-2025/blob/main/AIML_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
list1 = [1,2,3]
array1 = np.array(list1)
array1
# Out:
# array([1, 2, 3])

# %%
type(list1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
list2 = [3,2,1]
array2 = np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("multiplication:",array1 * array2)
print("division:",array2/array1)
print("power:",array2 ** array1)
print(f"{array2} raised to the power of {array1}:,{array2 ** array1}")
# Out:
# multiplication: [3 4 3]
# division: [3.         1.         0.33333333]
# power: [3 4 1]
# [3 2 1] raised to the power of [1 2 3]:,[3 4 1]

# %%
#sine function
print("sine function:",np.sin(array1))
# Out:
# sine function: [0.84147098 0.90929743 0.14112001]

# %%
#logorithms
print("Natural logorithms:",np.log(array1))
print("Base logorithms:",np.log10(array1))
print("Base-2 logorithms:",np.log2(array1))
# Out:
# Natural logorithms: [0.         0.69314718 1.09861229]
# Base logorithms: [0.         0.30103    0.47712125]
# Base-2 logorithms: [0.        1.        1.5849625]

# %%
#exponential
print("Exponential:",np.exp(array1))
# Out:
# Exponential: [ 2.71828183  7.3890561  20.08553692]

# %%
print("Adding two numpy arrays {array1} and {array2}:",array1 + array2)
# Out:
# Adding two numpy arrays {array1} and {array2}: [4 4 4]

# %%
print(f"Ading two numpy arrays {array1} and {array2}:{array1 + array2}")
# Out:
# Ading two numpy arrays [1 2 3] and [3 2 1]:[4 4 4]

# %%
people = ["Varsha","Rithika","Navaneeth","Sreeja","Sidhu","Tharun","Harini"]
age = [18, 19, 20, 18, 19, 15,21]
weight = [40, 50, 45, 42, 52, 60, 49]
height = [160, 140, 150, 100, 120, 160,180]

# %%
plt.scatter(people,age,color="blue",marker="*")
plt.title("Name & Age")
plt.xlabel("Names of people")
plt.ylabel("Ages of people")
# Out:
# Text(0, 0.5, 'Ages of people')

# %%
plt.bar(people,age,color="Red",width=0.6,edgecolor='k',alpha = 0.6)
plt.title("People's names and their ages",fontsize=20,fontstyle='italic')
plt.xlabel("Names of people",fontsize=16)
plt.ylabel("Ages of people",fontsize=16)
plt.show()

# %%
plt.hist(weight,color="pink",edgecolor="k",alpha=0.75,bins=5)
plt.title("Histogram of weights & heights of people",fontsize=18)
plt.xlabel("Weights of people")
plt.show()
